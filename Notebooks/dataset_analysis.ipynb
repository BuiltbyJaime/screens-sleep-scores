# %% [markdown]
# # Screens, Sleep & Scores

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset 1: Smartphone Usage and Addiction

# %% [markdown]
# In this section of the project, I explored how screen time habits relate to sleep, stress, and digital addiction. The smartphone_addiction dataset located in the Data folder includes a collection of user information such as age, gender, daily screen time, social media use, sleep hours, stress level, and addiction status.

# %%
df = pd.read_csv("../Data/smartphone_addiction.csv")

# %% [markdown]
# ##### Data Inspection

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# 1                    127                 71                 6.71       Medium
# 2                     44                106                 8.68         High
# 3                    178                107                 9.77         High
# 4                    136                177                12.55          Low
#
#   academic_work_impact addiction_level  addicted_label
# 0                  Yes             NaN               0
# 1                  Yes             NaN               0
# 2                   No            Mild               0
# 3                  Yes        Moderate               1
# 4                   No          Severe               1

# %%
df.tail()
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 7495       TXN07496  U07496   26   Other                     9.85
# 7496       TXN07497  U07497   35    Male                     5.67
# 7497       TXN07498  U07498   22  Female                     9.99
# 7498       TXN07499  U07499   23    Male                     8.74
# 7499       TXN07500  U07500   27  Female                    10.04
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 7495                1.75          3.13              3.49         5.81
# 7496                2.33          2.76              5.90         8.47
# 7497                3.61          1.09              1.16         8.17
# 7498                1.59          0.07              4.64         6.19
# 7499                5.40          0.73              5.45         5.58
#
#       notifications_per_day  app_opens_per_day  weekend_screen_time  \
# 7495                    249                122                11.99
# 7496                    197                 56                 7.08
# 7497                    207                 24                12.84
# 7498                    134                 62                10.52
# 7499                    215                 38                12.17
#
#      stress_level academic_work_impact addiction_level  addicted_label
# 7495          Low                  Yes        Moderate               1
# 7496          Low                   No             NaN               0
# 7497       Medium                  Yes          Severe               1
# 7498         High                  Yes          Severe               1
# 7499          Low                  Yes          Severe               1

# %%
df.shape
# Out:
# (7500, 16)

# %%
df.columns
# Out:
# Index(['transaction_id', 'user_id', 'age', 'gender', 'daily_screen_time_hours',
#        'social_media_hours', 'gaming_hours', 'work_study_hours', 'sleep_hours',
#        'notifications_per_day', 'app_opens_per_day', 'weekend_screen_time',
#        'stress_level', 'academic_work_impact', 'addiction_level',
#        'addicted_label'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           7500 non-null   str
#  1   user_id                  7500 non-null   str
#  2   age                      7500 non-null   int64
#  3   gender                   7500 non-null   str
#  4   daily_screen_time_hours  7500 non-null   float64
#  5   social_media_hours       7500 non-null   float64
#  6   gaming_hours             7500 non-null   float64
#  7   work_study_hours         7500 non-null   float64
#  8   sleep_hours              7500 non-null   float64
#  9   notifications_per_day    7500 non-null   int64
#  10  app_opens_per_day        7500 non-null   int64
#  11  weekend_screen_time      7500 non-null   float64
#  12  stress_level             7500 non-null   str
#  13  academic_work_impact     7500 non-null   str
#  14  addiction_level          6681 non-null   str
#  15  addicted_label           7500 non-null   int64
# dtypes: float64(6), int64(4), str(6)
# memory usage: 937.6 KB

# %%
df.dtypes
# Out:
# transaction_id                 str
# user_id                        str
# age                          int64
# gender                         str
# daily_screen_time_hours    float64
# social_media_hours         float64
# gaming_hours               float64
# work_study_hours           float64
# sleep_hours                float64
# notifications_per_day        int64
# app_opens_per_day            int64
# weekend_screen_time        float64
# stress_level                   str
# academic_work_impact           str
# addiction_level                str
# addicted_label               int64
# dtype: object

# %%
df.describe()
# Out:
#                age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# count  7500.000000              7500.000000         7500.000000   7500.000000
# mean     26.568800                 7.499912            3.273484      2.014183
# std       5.197108                 2.609188            1.585342      1.146039
# min      18.000000                 3.000000            0.500000      0.000000
# 25%      22.000000                 5.220000            1.910000      1.020000
# 50%      27.000000                 7.525000            3.270000      2.040000
# 75%      31.000000                 9.810000            4.630000      2.990000
# max      35.000000                12.000000            6.000000      4.000000
#
#        work_study_hours  sleep_hours  notifications_per_day  \
# count       7500.000000  7500.000000            7500.000000
# mean           3.242420     6.737561             134.257333
# std            1.600765     1.283605              66.586883
# min            0.500000     4.500000              20.000000
# 25%            1.850000     5.630000              76.000000
# 50%            3.230000     6.720000             134.000000
# 75%            4.640000     7.840000             191.000000
# max            6.000000     9.000000             250.000000
#
#        app_opens_per_day  weekend_screen_time  addicted_label
# count        7500.000000          7500.000000     7500.000000
# mean           97.832400             9.243827        0.707733
# std            48.423349             2.718281        0.454835
# min            15.000000             3.580000        0.000000
# 25%            55.000000             6.960000        0.000000
# 50%            98.000000             9.260000        1.000000
# 75%           140.000000            11.540000        1.000000
# max           180.000000            14.880000        1.000000

# %% [markdown]
# In the previous commands I explored the overall data and observed the columns and size of the dataset.

# %%
df["age"].describe()
# Out:
# count    7500.000000
# mean       26.568800
# std         5.197108
# min        18.000000
# 25%        22.000000
# 50%        27.000000
# 75%        31.000000
# max        35.000000
# Name: age, dtype: float64

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      2553
# Other     2486
# Female    2461
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['transaction_id', 'user_id', 'age', 'gender', 'daily_screen_time_hours',
#        'social_media_hours', 'gaming_hours', 'work_study_hours', 'sleep_hours',
#        'notifications_per_day', 'app_opens_per_day', 'weekend_screen_time',
#        'stress_level', 'academic_work_impact', 'addiction_level',
#        'addicted_label'],
#       dtype='str')

# %% [markdown]
# Value Counts for Categorical Columns

# %%
df['addiction_level'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0            NaN
# 1            NaN
# 2           Mild
# 3       Moderate
# 4         Severe
#           ...
# 7495    Moderate
# 7496         NaN
# 7497      Severe
# 7498      Severe
# 7499      Severe
# Name: addiction_level, Length: 7500, dtype: str>

# %%
df["stress_level"].value_counts()
# Out:
# stress_level
# High      2560
# Low       2503
# Medium    2437
# Name: count, dtype: int64

# %% [markdown]
# The distribution of the stress levels are not varied

# %%
df["addiction_level"].value_counts()
# Out:
# addiction_level
# Moderate    2874
# Severe      2434
# Mild        1373
# Name: count, dtype: int64

# %%
df["academic_work_impact"].value_counts()
# Out:
# academic_work_impact
# No     3753
# Yes    3747
# Name: count, dtype: int64

# %% [markdown]
# Missing Values

# %%
df.isna().sum()
# Out:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
df[df["addiction_level"].isna()]
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0          TXN00001  U00001   21    Male                     3.23
# 1          TXN00002  U00002   24   Other                     5.09
# 8          TXN00009  U00009   21   Other                     4.38
# 11         TXN00012  U00012   27   Other                     5.16
# 13         TXN00014  U00014   32    Male                     4.09
# ...             ...     ...  ...     ...                      ...
# 7447       TXN07448  U07448   20  Female                     5.00
# 7454       TXN07455  U07455   29   Other                     3.45
# 7457       TXN07458  U07458   29  Female                     3.11
# 7481       TXN07482  U07482   29    Male                     4.72
# 7496       TXN07497  U07497   35    Male                     5.67
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                   2.01          0.89              4.55         7.55
# 1                   3.81          2.24              4.44         7.66
# 8                   1.38          2.72              3.78         6.23
# 11                  1.82          2.27              0.93         7.79
# 13                  1.74          1.35              3.74         5.54
# ...                  ...           ...               ...          ...
# 7447                1.68          2.87              1.02         6.67
# 7454                3.95          1.20              1.24         7.51
# 7457                2.44          3.17              0.84         8.93
# 7481                3.65          0.78              2.58         5.15
# 7496                2.33          2.76              5.90         8.47
#
#       notifications_per_day  app_opens_per_day  weekend_screen_time  \
# 0                       248                154                 3.95
# 1                       127                 71                 6.71
# 8                       172                134                 6.20
# 11                      228                 32                 8.10
# 13                       76                 16                 4.77
# ...                     ...                ...                  ...
# 7447                    237                 26                 5.87
# 7454                     25                 84                 5.19
# 7457                    217                174                 4.27
# 7481                     20                 76                 6.02
# 7496                    197                 56                 7.08
#
#      stress_level academic_work_impact addiction_level  addicted_label
# 0          Medium                  Yes             NaN               0
# 1          Medium                  Yes             NaN               0
# 8            High                  Yes             NaN               0
# 11           High                  Yes             NaN               0
# 13           High                  Yes             NaN               0
# ...           ...                  ...             ...             ...
# 7447       Medium                  Yes             NaN               0
# 7454         High                   No             NaN               0
# 7457         High                  Yes             NaN               0
# 7481       Medium                   No             NaN               0
# 7496          Low                   No             NaN               0
#
# [819 rows x 16 columns]

# %% [markdown]
# It seems that the addition level from the csv is from none, moderate, and to severe.  I need to change the scale from 1 to 3 so I am able to include that column.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['age']<25]
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0          TXN00001  U00001   21    Male                     3.23
# 1          TXN00002  U00002   24   Other                     5.09
# 8          TXN00009  U00009   21   Other                     4.38
# 14         TXN00015  U00015   19    Male                    10.74
# 15         TXN00016  U00016   21    Male                     3.87
# ...             ...     ...  ...     ...                      ...
# 7490       TXN07491  U07491   21  Female                     3.08
# 7493       TXN07494  U07494   19  Female                    10.41
# 7494       TXN07495  U07495   23   Other                     6.65
# 7497       TXN07498  U07498   22  Female                     9.99
# 7498       TXN07499  U07499   23    Male                     8.74
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                   2.01          0.89              4.55         7.55
# 1                   3.81          2.24              4.44         7.66
# 8                   1.38          2.72              3.78         6.23
# 14                  0.89          0.95              4.18         5.46
# 15                  2.87          1.69              3.07         7.78
# ...                  ...           ...               ...          ...
# 7490                5.68          3.57              5.53         4.89
# 7493                3.32          3.88              5.58         6.77
# 7494                4.56          1.31              5.09         5.71
# 7497                3.61          1.09              1.16         8.17
# 7498                1.59          0.07              4.64         6.19
#
#       notifications_per_day  app_opens_per_day  weekend_screen_time  \
# 0                       248                154                 3.95
# 1                       127                 71                 6.71
# 8                       172                134                 6.20
# 14                       53                161                12.68
# 15                      192                180                 4.62
# ...                     ...                ...                  ...
# 7490                     41                104                 5.82
# 7493                    122                 96                10.93
# 7494                     78                 77                 7.43
# 7497                    207                 24                12.84
# 7498                    134                 62                10.52
#
#      stress_level academic_work_impact addiction_level  addicted_label
# 0          Medium                  Yes             NaN               0
# 1          Medium                  Yes             NaN               0
# 8            High                  Yes             NaN               0
# 14            Low                   No          Severe               1
# 15         Medium                   No             NaN               0
# ...           ...                  ...             ...             ...
# 7490         High                   No          Severe               1
# 7493          Low                  Yes          Severe               1
# 7494       Medium                   No          Severe               1
# 7497       Medium                  Yes          Severe               1
# 7498         High                  Yes          Severe               1
#
# [2867 rows x 16 columns]

# %%
df[df['age']>39]
# Out:
# Empty DataFrame
# Columns: [transaction_id, user_id, age, gender, daily_screen_time_hours, social_media_hours, gaming_hours, work_study_hours, sleep_hours, notifications_per_day, app_opens_per_day, weekend_screen_time, stress_level, academic_work_impact, addiction_level, addicted_label]
# Index: []

# %% [markdown]
# For this section I filtered the data to see the range of ages as well understand how the filtering works. I realized that there would be a cut off in age because older adults are not typically in education therefore their academic levels would not exist.

# %% [markdown]
# ##### Data Cleaning

# %%
addiction_scale = {
    'None': 0,
    'Mild': 1,
    'Moderate': 2,
    'Severe': 3
}

df['addiction_level_numeric'] = df['addiction_level'].map(addiction_scale)
df[['addiction_level', 'addiction_level_numeric']].head()
# Out:
#   addiction_level  addiction_level_numeric
# 0             NaN                      NaN
# 1             NaN                      NaN
# 2            Mild                      1.0
# 3        Moderate                      2.0
# 4          Severe                      3.0

# %% [markdown]
# I changed the data to numeric so it is easier to compare and manage

# %%
df = df.drop(columns=["transaction_id"])

# %% [markdown]
# I decided to drop transaction_id because it did not serve a purpose.

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df['age'] = df['age'].astype(int)
df['addicted_label'] = df['addicted_label'].astype(int)

# %%
df['addicted_status'] = df['addicted_label'].map({
    0: 'Not Addicted',
    1: 'Addicted'
})

# %% [markdown]
# For this I needed to change the labels to 1s and zeros that way I would be able to quantify them. I also removed duplicate rows and dropped missing values so the analysis would be based on complete records. I finally converted key columns into the correct data types.

# %%
df.groupby('addicted_status')[['daily_screen_time_hours', 'sleep_hours']].mean()
# Out:
#                  daily_screen_time_hours  sleep_hours
# addicted_status
# Addicted                        8.467502     6.766839
# Not Addicted                    5.535062     6.660153

# %%
df['addiction_level'].value_counts(dropna=False)
# Out:
# addiction_level
# Moderate    2874
# Severe      2434
# Mild        1373
# Name: count, dtype: int64

# %% [markdown]
# I was running into an error here with no values presenting for none therefore I was checking before using the data for my charts.

# %% [markdown]
# #  Dataset 1: Visualizations

# %% [markdown]
# ### Daily Screen Time by Addiction Level

# %% [markdown]
# 1. Does higher screen time relate to higher addiction levels?

# %%
plt.figure(figsize=(8,6))

sns.boxplot(
    data=df,
    x='addiction_level',
    y='daily_screen_time_hours',
    order=[ 'Mild', 'Moderate', 'Severe']
)

plt.title('Daily Screen Time by Addiction Level')

plt.xlabel('Addiction Level')
plt.ylabel('Daily Screen Time (Hours)')

plt.show()

# %% [markdown]
# The chart examines whether daily screen time differs across addiction levels. Higher median screen time in the higher addiction categories would suggest an association between greater screen use and greater reported addiction severity.
#
# A boxplot was chosen because it clearly shows the spread, median, and variation in screen time across each addiction category. The addiction levels were ordered from `Mild` to `Severe` to show progression clearly.

# %% [markdown]
# ### Academic Impact

# %% [markdown]
# 2. Is screen addiction associated with negative academic impact?

# %%
plt.figure(figsize=(8,6))

sns.countplot(
    data=df,
    x='addiction_level',
    hue='academic_work_impact',
    order=['Mild', 'Moderate', 'Severe']
)

plt.title('Academic Impact Across Addiction Levels')

plt.xlabel('Addiction Level')
plt.ylabel('Number of Users')

plt.legend(title='Academic Work Impact')

plt.show()

# %% [markdown]
# ### Academic Impact Across Addiction Levels
# The data is strange for this chart as the number of users for each category of severity are similar. This chart suggests that users in the moderate and severe addiction categories more frequently reported academic impact compared to users with lower addiction levels.
#
# A grouped bar chart was chosen because it clearly compares categorical responses across each addiction category. Clear labels and consistent scaling were used to keep the comparison easy to interpret. Finally blue and orange was selected because the colors are contrasting.

# %% [markdown]
# ### Notifications Per Day

# %% [markdown]
# 3. “Do users who receive more notifications spend more time on their devices?”

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x='notifications_per_day',
    y='daily_screen_time_hours',
    alpha=0.6,
    size = 20 
)
plt.title('Notifications per Day vs Daily Screen Time')

plt.xlabel('Notifications Per Day')
plt.ylabel('Daily Screen Time (Hours)')

plt.show()

# %% [markdown]
# In this chart there was no correlation presented with the number of notifications and screen time therefore.   I need to explore this further as there may have been a better comparison to be explored or if my data does have something wrong with it.  However, notifications and screen time do not appear meaningfully related from the chart.

# %% [markdown]
# ### Gender Distribution of Addicted Users

# %% [markdown]
# “What is the gender distribution of users classified as addicted?”

# %%
addicted_users = df[df['addicted_label'] == 1]

gender_counts = addicted_users['gender'].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    gender_counts.values,
    labels=gender_counts.index,
    autopct='%1.1f%%'
)

plt.title('Gender Distribution of Addicted Users')

plt.show()

# %% [markdown]
# I finally wanted to explore the distribution of addiction levels across gender groups. A pie chart was chosen because it clearly shows the proportion each gender contributes to the addicted user population.
#
# At this stage of the analysis, the dataset also appeared highly uniform, with relatively low variance across several variables. This made some patterns appear less natural and suggests the data may be simplified or artificially generated rather than fully representative of real-world behaviour.

# %% [markdown]
# # Dataset 2: Student Insomnia and Educational Outcomes

# %% [markdown]
# ##### Data Inspection

# %%
df2 = pd.read_csv("../Data/student_educational_outcomes.csv")

# %%
print(df2.shape)
# Out:
# (791, 16)

# %% [markdown]
# The dataset contains 791 student responses and 16 variables.

# %%
df2.head()
# Out:
#              Timestamp 1. What is your year of study? 2. What is your gender?  \
# 0  10/24/2024 16:51:15               Graduate student                    Male
# 1  10/24/2024 16:51:51                     Third year                    Male
# 2  10/24/2024 16:52:21                     First year                  Female
# 3  10/24/2024 16:53:00                     Third year                    Male
# 4  10/24/2024 16:53:25               Graduate student                    Male
#
#   3. How often do you have difficulty falling asleep at night?   \
# 0                           Often (5-6 times a week)
# 1                           Often (5-6 times a week)
# 2                       Sometimes (3-4 times a week)
# 3                           Often (5-6 times a week)
# 4                           Often (5-6 times a week)
#
#   4. On average, how many hours of sleep do you get on a typical day?  \
# 0                                          7-8 hours
# 1                                          7-8 hours
# 2                                          7-8 hours
# 3                                  More than 8 hours
# 4                                          7-8 hours
#
#   5. How often do you wake up during the night and have trouble falling back asleep?  \
# 0                           Often (5-6 times a week)
# 1                           Often (5-6 times a week)
# 2                       Sometimes (3-4 times a week)
# 3                       Sometimes (3-4 times a week)
# 4                           Often (5-6 times a week)
#
#   6. How would you rate the overall quality of your sleep?  \
# 0                                               Good
# 1                                               Good
# 2                                               Good
# 3                                               Poor
# 4                                          Very good
#
#   7. How often do you experience difficulty concentrating during lectures or studying due to lack of sleep?  \
# 0                                          Sometimes
# 1                                              Often
# 2                                              Often
# 3                                              Often
# 4                                             Always
#
#   8. How often do you feel fatigued during the day, affecting your ability to study or attend classes?  \
# 0                                              Often
# 1                                          Sometimes
# 2                                              Often
# 3                                              Often
# 4                                          Sometimes
#
#   9. How often do you miss or skip classes due to sleep-related issues (e.g., insomnia, feeling tired)?  \
# 0                           Often (3-4 times a week)
# 1                       Sometimes (1-2 times a week)
# 2                       Sometimes (1-2 times a week)
# 3                         Rarely (1-2 times a month)
# 4                       Sometimes (1-2 times a week)
#
#   10. How would you describe the impact of insufficient sleep on your ability to complete assignments and meet deadlines?  \
# 0                                    Moderate impact
# 1                                       Major impact
# 2                                       Major impact
# 3                                       Minor impact
# 4                                    Moderate impact
#
#   11. How often do you use electronic devices (e.g., phone, computer) before going to sleep?  \
# 0                           Often (5-6 times a week)
# 1                       Sometimes (3-4 times a week)
# 2                           Often (5-6 times a week)
# 3                       Sometimes (3-4 times a week)
# 4                       Sometimes (3-4 times a week)
#
#   12. How often do you consume caffeine (coffee, energy drinks) to stay awake or alert?  \
# 0                          Rarely (1-2 times a week)
# 1                       Sometimes (3-4 times a week)
# 2                           Often (5-6 times a week)
# 3                       Sometimes (3-4 times a week)
# 4                       Sometimes (3-4 times a week)
#
#   13. How often do you engage in physical activity or exercise?  \
# 0                       Sometimes (3-4 times a week)
# 1                       Sometimes (3-4 times a week)
# 2                           Often (5-6 times a week)
# 3                                          Every day
# 4                           Often (5-6 times a week)
#
#   14. How would you describe your stress levels related to academic workload?  \
# 0                                        High stress
# 1                                         Low stress
# 2                                        High stress
# 3                              Extremely high stress
# 4                                         Low stress
#
#   15. How would you rate your overall academic performance (GPA or grades) in the past semester?
# 0                                            Average
# 1                                               Good
# 2                                      Below Average
# 3                                          Excellent
# 4                                            Average

# %%
df2.tail()
# Out:
#               Timestamp 1. What is your year of study?  \
# 786  11/6/2024 19:10:52                     Third year
# 787  11/6/2024 19:11:25               Graduate student
# 788  11/6/2024 19:12:31               Graduate student
# 789  11/6/2024 19:14:33               Graduate student
# 790  11/6/2024 19:15:41                     Third year
#
#     2. What is your gender?  \
# 786                    Male
# 787                    Male
# 788                    Male
# 789                    Male
# 790                    Male
#
#     3. How often do you have difficulty falling asleep at night?   \
# 786                                        Every night
# 787                           Often (5-6 times a week)
# 788                                        Every night
# 789                                        Every night
# 790                                        Every night
#
#     4. On average, how many hours of sleep do you get on a typical day?  \
# 786                                  More than 8 hours
# 787                                  More than 8 hours
# 788                                  More than 8 hours
# 789                                          7-8 hours
# 790                                  More than 8 hours
#
#     5. How often do you wake up during the night and have trouble falling back asleep?  \
# 786                                        Every night
# 787                           Often (5-6 times a week)
# 788                           Often (5-6 times a week)
# 789                                        Every night
# 790                           Often (5-6 times a week)
#
#     6. How would you rate the overall quality of your sleep?  \
# 786                                          Very poor
# 787                                               Poor
# 788                                          Very poor
# 789                                            Average
# 790                                               Poor
#
#     7. How often do you experience difficulty concentrating during lectures or studying due to lack of sleep?  \
# 786                                             Always
# 787                                              Often
# 788                                             Always
# 789                                              Often
# 790                                              Often
#
#     8. How often do you feel fatigued during the day, affecting your ability to study or attend classes?  \
# 786                                              Often
# 787                                             Always
# 788                                              Often
# 789                                              Often
# 790                                              Often
#
#     9. How often do you miss or skip classes due to sleep-related issues (e.g., insomnia, feeling tired)?  \
# 786                           Often (3-4 times a week)
# 787                           Often (3-4 times a week)
# 788                                             Always
# 789                           Often (3-4 times a week)
# 790                           Often (3-4 times a week)
#
#     10. How would you describe the impact of insufficient sleep on your ability to complete assignments and meet deadlines?  \
# 786                                       Major impact
# 787                                      Severe impact
# 788                                      Severe impact
# 789                                      Severe impact
# 790                                      Severe impact
#
#     11. How often do you use electronic devices (e.g., phone, computer) before going to sleep?  \
# 786                                        Every night
# 787                                        Every night
# 788                           Often (5-6 times a week)
# 789                                        Every night
# 790                           Often (5-6 times a week)
#
#     12. How often do you consume caffeine (coffee, energy drinks) to stay awake or alert?  \
# 786                           Often (5-6 times a week)
# 787                                          Every day
# 788                           Often (5-6 times a week)
# 789                                          Every day
# 790                                          Every day
#
#     13. How often do you engage in physical activity or exercise?  \
# 786                                          Every day
# 787                                          Every day
# 788                                          Every day
# 789                                          Every day
# 790                           Often (5-6 times a week)
#
#     14. How would you describe your stress levels related to academic workload?  \
# 786                              Extremely high stress
# 787                              Extremely high stress
# 788                              Extremely high stress
# 789                                        High stress
# 790                              Extremely high stress
#
#     15. How would you rate your overall academic performance (GPA or grades) in the past semester?
# 786                                            Average
# 787                                               Poor
# 788                                               Poor
# 789                                      Below Average
# 790                                               Poor

# %% [markdown]
# From this I can see that I will likely be dropping the timestamp column as well as changing the column values to numbers that can be later be used for visualizations.

# %%
df2.columns
# Out:
# Index(['Timestamp', '1. What is your year of study?',
#        '2. What is your gender?',
#        '3. How often do you have difficulty falling asleep at night? ',
#        '4. On average, how many hours of sleep do you get on a typical day?',
#        '5. How often do you wake up during the night and have trouble falling back asleep?',
#        '6. How would you rate the overall quality of your sleep?',
#        '7. How often do you experience difficulty concentrating during lectures or studying due to lack of sleep?',
#        '8. How often do you feel fatigued during the day, affecting your ability to study or attend classes?',
#        '9. How often do you miss or skip classes due to sleep-related issues (e.g., insomnia, feeling tired)?',
#        '10. How would you describe the impact of insufficient sleep on your ability to complete assignments and meet deadlines?',
#        '11. How often do you use electronic devices (e.g., phone, computer) before going to sleep?',
#        '12. How often do you consume caffeine (coffee, energy drinks) to stay awake or alert?',
#        '13. How often do you engage in physical activity or exercise?',
#        '14. How would you describe your stress levels related to academic workload?',
#        '15. How would you rate your overall academic performance (GPA or grades) in the past semester?'],
#       dtype='str')

# %%
def category_summary(dataframe, column=None):

    if column is not None:
        counts = dataframe[column].value_counts(dropna=False)

        percentages = (
            dataframe[column]
            .value_counts(normalize=True, dropna=False)
            .mul(100)
            .round(1)
        )

        return pd.DataFrame({
            "count": counts,
            "percentage": percentages
        })

    else:
        summaries = {}

        for col in dataframe.columns:
            counts = dataframe[col].value_counts(dropna=False)

            percentages = (
                dataframe[col]
                .value_counts(normalize=True, dropna=False)
                .mul(100)
                .round(1)
            )

            summaries[col] = pd.DataFrame({
                "count": counts,
                "percentage": percentages
            })

        return summaries

# %% [markdown]
# In this function, I take two inputs which are the dataframe and whichever column I want and it returns the count of each value as well as its percentage.v

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year_of_study              791 non-null    str
#  1   gender                     791 non-null    str
#  2   difficulty_falling_asleep  791 non-null    str
#  3   sleep_duration             791 non-null    str
#  4   night_waking               791 non-null    str
#  5   sleep_quality              791 non-null    str
#  6   concentration_difficulty   791 non-null    str
#  7   daytime_fatigue            791 non-null    str
#  8   missed_classes             791 non-null    str
#  9   assignment_impact          791 non-null    str
#  10  device_use_before_bed      791 non-null    str
#  11  caffeine_use               791 non-null    str
#  12  physical_activity          791 non-null    str
#  13  academic_stress            791 non-null    str
#  14  academic_performance       791 non-null    str
# dtypes: str(15)
# memory usage: 92.8 KB

# %% [markdown]
# All variables are currently stored as strings because most responses are categorical survey data. The initial inspection also indicates that all columns contain complete observations.

# %%
df2.describe()
# Out:
#            year_of_study gender difficulty_falling_asleep sleep_duration  \
# count                791    791                       791            791
# unique                 4      2                         5              5
# top     Graduate student   Male  Often (5-6 times a week)      7-8 hours
# freq                 403    572                       369            423
#
#                     night_waking sleep_quality concentration_difficulty  \
# count                        791           791                      791
# unique                         5             5                        5
# top     Often (5-6 times a week)     Very poor                    Often
# freq                         411           246                      427
#
#        daytime_fatigue            missed_classes assignment_impact  \
# count              791                       791               791
# unique               5                         5                 5
# top              Often  Often (3-4 times a week)      Major impact
# freq               399                       431               398
#
#            device_use_before_bed              caffeine_use  \
# count                        791                       791
# unique                         5                         5
# top     Often (5-6 times a week)  Often (5-6 times a week)
# freq                         431                       422
#
#                physical_activity        academic_stress academic_performance
# count                        791                    791                  791
# unique                         5                      4                    5
# top     Often (5-6 times a week)  Extremely high stress                 Poor
# freq                         392                    373                  419

# %% [markdown]
# There are no columns that have exagerated unique values. And this will be helpful when needing to change the colmun values.

# %%
df2.isnull().sum()
# Out:
# year_of_study                0
# gender                       0
# difficulty_falling_asleep    0
# sleep_duration               0
# night_waking                 0
# sleep_quality                0
# concentration_difficulty     0
# daytime_fatigue              0
# missed_classes               0
# assignment_impact            0
# device_use_before_bed        0
# caffeine_use                 0
# physical_activity            0
# academic_stress              0
# academic_performance         0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# year_of_study                0
# gender                       0
# difficulty_falling_asleep    0
# sleep_duration               0
# night_waking                 0
# sleep_quality                0
# concentration_difficulty     0
# daytime_fatigue              0
# missed_classes               0
# assignment_impact            0
# device_use_before_bed        0
# caffeine_use                 0
# physical_activity            0
# academic_stress              0
# academic_performance         0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# np.int64(18)

# %%
df2[df2.duplicated()]
# Out:
#         year_of_study  gender difficulty_falling_asleep     sleep_duration  \
# 265  Graduate student  Female               Every night  More than 8 hours
# 288  Graduate student    Male               Every night  More than 8 hours
# 308  Graduate student    Male               Every night  More than 8 hours
# 409  Graduate student  Female               Every night  More than 8 hours
# 433  Graduate student    Male               Every night  More than 8 hours
# 441  Graduate student    Male               Every night  More than 8 hours
# 444  Graduate student    Male               Every night  More than 8 hours
# 445  Graduate student    Male               Every night  More than 8 hours
# 446  Graduate student    Male               Every night  More than 8 hours
# 448  Graduate student  Female               Every night  More than 8 hours
# 498        Third year    Male  Often (5-6 times a week)          7-8 hours
# 623        Third year  Female  Often (5-6 times a week)          7-8 hours
# 627        Third year    Male  Often (5-6 times a week)  More than 8 hours
# 697        Third year    Male  Often (5-6 times a week)          7-8 hours
# 702        Third year    Male  Often (5-6 times a week)          7-8 hours
# 704        Third year    Male  Often (5-6 times a week)          7-8 hours
# 711  Graduate student    Male               Every night          7-8 hours
# 718        Third year    Male  Often (5-6 times a week)          7-8 hours
#
#                  night_waking sleep_quality concentration_difficulty  \
# 265               Every night     Very good                   Always
# 288  Often (5-6 times a week)          Good                   Always
# 308               Every night     Very good                   Always
# 409               Every night     Very good                   Always
# 433               Every night     Very poor                   Always
# 441               Every night     Very poor                   Always
# 444               Every night     Very poor                   Always
# 445               Every night     Very poor                   Always
# 446               Every night     Very poor                   Always
# 448               Every night     Very poor                   Always
# 498  Often (5-6 times a week)     Very poor                    Often
# 623  Often (5-6 times a week)     Very poor                    Often
# 627  Often (5-6 times a week)          Poor                    Often
# 697               Every night     Very poor                    Often
# 702  Often (5-6 times a week)       Average                    Often
# 704  Often (5-6 times a week)          Good                    Often
# 711  Often (5-6 times a week)          Poor                    Often
# 718               Every night          Poor                    Often
#
#     daytime_fatigue            missed_classes assignment_impact  \
# 265          Always                    Always      Major impact
# 288          Always                    Always     Severe impact
# 308          Always                    Always     Severe impact
# 409          Always  Often (3-4 times a week)     Severe impact
# 433          Always                    Always      Major impact
# 441          Always                    Always     Severe impact
# 444          Always                    Always     Severe impact
# 445          Always                    Always     Severe impact
# 446          Always                    Always     Severe impact
# 448          Always                    Always     Severe impact
# 498           Often  Often (3-4 times a week)      Major impact
# 623           Often  Often (3-4 times a week)      Major impact
# 627           Often  Often (3-4 times a week)      Major impact
# 697           Often  Often (3-4 times a week)      Major impact
# 702           Often  Often (3-4 times a week)      Major impact
# 704           Often  Often (3-4 times a week)      Major impact
# 711           Often  Often (3-4 times a week)      Major impact
# 718           Often  Often (3-4 times a week)      Major impact
#
#         device_use_before_bed              caffeine_use  \
# 265               Every night                 Every day
# 288  Often (5-6 times a week)  Often (5-6 times a week)
# 308               Every night                 Every day
# 409  Often (5-6 times a week)                 Every day
# 433               Every night                 Every day
# 441               Every night                 Every day
# 444               Every night                 Every day
# 445               Every night                 Every day
# 446               Every night                 Every day
# 448               Every night                 Every day
# 498  Often (5-6 times a week)  Often (5-6 times a week)
# 623  Often (5-6 times a week)  Often (5-6 times a week)
# 627  Often (5-6 times a week)  Often (5-6 times a week)
# 697  Often (5-6 times a week)  Often (5-6 times a week)
# 702  Often (5-6 times a week)  Often (5-6 times a week)
# 704  Often (5-6 times a week)  Often (5-6 times a week)
# 711  Often (5-6 times a week)  Often (5-6 times a week)
# 718  Often (5-6 times a week)  Often (5-6 times a week)
#
#                 physical_activity        academic_stress academic_performance
# 265      Often (5-6 times a week)  Extremely high stress                 Poor
# 288                     Every day  Extremely high stress                 Poor
# 308                     Every day  Extremely high stress                 Poor
# 409                     Every day  Extremely high stress        Below Average
# 433                     Every day  Extremely high stress                 Poor
# 441                     Every day  Extremely high stress                 Poor
# 444                     Every day  Extremely high stress                 Poor
# 445                     Every day  Extremely high stress                 Poor
# 446                     Every day  Extremely high stress                 Poor
# 448                     Every day  Extremely high stress                 Poor
# 498      Often (5-6 times a week)            High stress                 Poor
# 623  Sometimes (3-4 times a week)            High stress        Below Average
# 627      Often (5-6 times a week)  Extremely high stress        Below Average
# 697      Often (5-6 times a week)            High stress                 Poor
# 702      Often (5-6 times a week)            High stress              Average
# 704      Often (5-6 times a week)            High stress        Below Average
# 711      Often (5-6 times a week)            High stress        Below Average
# 718      Often (5-6 times a week)            High stress                 Poor

# %% [markdown]
# Although there are duplicates, it seems that these are unique students that have answered similarly. There are also no null values.

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# The column names are really long, therefore I am going to rename them so it is easier to work with and so anyone can quickly look.

# %%
df2.columns = [ "timestamps" ,"year_of_study", "gender", "difficulty_falling_asleep", "sleep_duration", "night_waking", "sleep_quality", "concentration_difficulty", "daytime_fatigue", "missed_classes", "assignment_impact", "device_use_before_bed", "caffeine_use", "physical_activity", "academic_stress", "academic_performance" ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[297], line 1
# ----> 1 df2.columns = [ "timestamps" ,"year_of_study", "gender", "difficulty_falling_asleep", "sleep_duration", "night_waking", "sleep_quality", "concentration_difficulty", "daytime_fatigue", "missed_classes", "assignment_impact", "device_use_before_bed", "caffeine_use", "physical_activity", "academic_stress", "academic_performance" ]
#
# File ~/Projects/screens-sleep-scores/.venv/lib/python3.14/site-packages/pandas/core/generic.py:6209, in NDFrame.__setattr__(self, name, value)
#    6205
#    6206         try:
#    6207             object.__getattribute__(self, name)
#    6208             return object.__setattr__(self, name, value)
# -> 6209         except AttributeError:
#    6210             pass
#    6211
#    6212         # if this fails, go on to more involved attribute setting
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Projects/screens-sleep-scores/.venv/lib/python3.14/site-packages/pandas/core/generic.py:754, in NDFrame._set_axis(self, axis, labels)
#     750         This is called from the cython code when we set the `index` attribute
#     751         directly, e.g. `series.index = [1, 2, 3]`.
#     752         """
#     753         labels = ensure_index(labels)
# --> 754         self._mgr.set_axis(axis, labels)
#
# File ~/Projects/screens-sleep-scores/.venv/lib/python3.14/site-packages/pandas/core/internals/managers.py:273, in BaseBlockManager.set_axis(self, axis, new_labels)
#     271 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     272     # Caller is responsible for ensuring we have an Index object.
# --> 273     self._validate_set_axis(axis, new_labels)
#     274     self.axes[axis] = new_labels
#
# File ~/Projects/screens-sleep-scores/.venv/lib/python3.14/site-packages/pandas/core/internals/managers.py:288, in BaseBlockManager._validate_set_axis(self, axis, new_labels)
#     285     pass
#     287 elif new_len != old_len:
# --> 288     raise ValueError(
#     289         f"Length mismatch: Expected axis has {old_len} elements, new "
#     290         f"values have {new_len} elements"
#     291     )
#
# ValueError: Length mismatch: Expected axis has 15 elements, new values have 16 elements

# %%
df2.head()
# Out:
#             timestamps     year_of_study  gender  \
# 0  10/24/2024 16:51:15  Graduate student    Male
# 1  10/24/2024 16:51:51        Third year    Male
# 2  10/24/2024 16:52:21        First year  Female
# 3  10/24/2024 16:53:00        Third year    Male
# 4  10/24/2024 16:53:25  Graduate student    Male
#
#       difficulty_falling_asleep     sleep_duration  \
# 0      Often (5-6 times a week)          7-8 hours
# 1      Often (5-6 times a week)          7-8 hours
# 2  Sometimes (3-4 times a week)          7-8 hours
# 3      Often (5-6 times a week)  More than 8 hours
# 4      Often (5-6 times a week)          7-8 hours
#
#                    night_waking sleep_quality concentration_difficulty  \
# 0      Often (5-6 times a week)          Good                Sometimes
# 1      Often (5-6 times a week)          Good                    Often
# 2  Sometimes (3-4 times a week)          Good                    Often
# 3  Sometimes (3-4 times a week)          Poor                    Often
# 4      Often (5-6 times a week)     Very good                   Always
#
#   daytime_fatigue                missed_classes assignment_impact  \
# 0           Often      Often (3-4 times a week)   Moderate impact
# 1       Sometimes  Sometimes (1-2 times a week)      Major impact
# 2           Often  Sometimes (1-2 times a week)      Major impact
# 3           Often    Rarely (1-2 times a month)      Minor impact
# 4       Sometimes  Sometimes (1-2 times a week)   Moderate impact
#
#           device_use_before_bed                  caffeine_use  \
# 0      Often (5-6 times a week)     Rarely (1-2 times a week)
# 1  Sometimes (3-4 times a week)  Sometimes (3-4 times a week)
# 2      Often (5-6 times a week)      Often (5-6 times a week)
# 3  Sometimes (3-4 times a week)  Sometimes (3-4 times a week)
# 4  Sometimes (3-4 times a week)  Sometimes (3-4 times a week)
#
#               physical_activity        academic_stress academic_performance
# 0  Sometimes (3-4 times a week)            High stress              Average
# 1  Sometimes (3-4 times a week)             Low stress                 Good
# 2      Often (5-6 times a week)            High stress        Below Average
# 3                     Every day  Extremely high stress            Excellent
# 4      Often (5-6 times a week)             Low stress              Average

# %%
df2 = df2.drop(columns=["timestamps"])

# %%
df2_focus = df2[
    [
        "sleep_quality",
        "difficulty_falling_asleep",
        "academic_performance",
        "device_use_before_bed",
        "gender"
    ]
].copy()

# %% [markdown]
# I will be just focusing on device use before bed, sleep quality,  difficulty falling asleep, and academic performance in order to keep with the theme of my Research Questions.

# %%
df2_focus
# Out:
#     sleep_quality     difficulty_falling_asleep academic_performance  \
# 0            Good      Often (5-6 times a week)              Average
# 1            Good      Often (5-6 times a week)                 Good
# 2            Good  Sometimes (3-4 times a week)        Below Average
# 3            Poor      Often (5-6 times a week)            Excellent
# 4       Very good      Often (5-6 times a week)              Average
# ..            ...                           ...                  ...
# 786     Very poor                   Every night              Average
# 787          Poor      Often (5-6 times a week)                 Poor
# 788     Very poor                   Every night                 Poor
# 789       Average                   Every night        Below Average
# 790          Poor                   Every night                 Poor
#
#             device_use_before_bed  gender
# 0        Often (5-6 times a week)    Male
# 1    Sometimes (3-4 times a week)    Male
# 2        Often (5-6 times a week)  Female
# 3    Sometimes (3-4 times a week)    Male
# 4    Sometimes (3-4 times a week)    Male
# ..                            ...     ...
# 786                   Every night    Male
# 787                   Every night    Male
# 788      Often (5-6 times a week)    Male
# 789                   Every night    Male
# 790      Often (5-6 times a week)    Male
#
# [791 rows x 5 columns]

# %%
df2_focus.shape
# Out:
# (791, 5)

# %%
category_summary(df2, "difficulty_falling_asleep")
# Out:
#                               count  percentage
# difficulty_falling_asleep
# Often (5-6 times a week)        369        46.6
# Every night                     366        46.3
# Sometimes (3-4 times a week)     40         5.1
# Rarely (1-2 times a week)         9         1.1
# Never                             7         0.9

# %%
category_summary(df2, "academic_stress")
# Out:
#                        count  percentage
# academic_stress
# Extremely high stress    373        47.2
# High stress              366        46.3
# Low stress                46         5.8
# No stress                  6         0.8

# %%
category_summary(df2, "sleep_quality")
# Out:
#                count  percentage
# sleep_quality
# Very poor        246        31.1
# Very good        204        25.8
# Good             170        21.5
# Poor             125        15.8
# Average           46         5.8

# %%
category_summary(df2, "academic_performance")
# Out:
#                       count  percentage
# academic_performance
# Poor                    419        53.0
# Below Average           297        37.5
# Average                  52         6.6
# Good                     17         2.1
# Excellent                 6         0.8

# %%
category_summary(df2, "device_use_before_bed")
# Out:
#                               count  percentage
# device_use_before_bed
# Often (5-6 times a week)        431        54.5
# Every night                     258        32.6
# Sometimes (3-4 times a week)     76         9.6
# Rarely (1-2 times a week)        24         3.0
# Never                             2         0.3

# %% [markdown]
# ##### Exploratory Data Analysis
